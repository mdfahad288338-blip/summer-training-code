# %% [markdown]
# # pandas

# %% [raw]
# it is basically panel data

# %% [raw]
# FEATURE OF PANDAS
# --statistical info
# --easy to apply formulas
# --easy to read data
# --data filteration easy
# --data infomation gathering

# %%
import pandas as pd

# %%
df = pd.DataFrame({ "Name" : ["Fahad","Ali","Saqib","Sahil"],"Marks":[8,8,9,7]})

# %%
df
# Out:
#     Name  Marks
# 0  Fahad      8
# 1    Ali      8
# 2  Saqib      9
# 3  Sahil      7

# %%
df.duplicated() #shows false because it check only the indexes
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.duplicated("Marks") #shows according to marks if same prints true
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool
