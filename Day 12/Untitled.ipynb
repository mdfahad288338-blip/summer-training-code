# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df =pd.read_csv('student_data.csv')

# %%
df = df.drop_duplicates()

# %%
selected_columns = [
    'studytime',
    'failures',
    'absences',
    'age',
    'traveltime',
    'famrel',
    'freetime',
    'goout',
    'G1',
    'G2',
    'G3'
    
]
df = df[selected_columns]

# %%
df
# Out:
#      studytime  failures  absences  age  traveltime  famrel  freetime  goout  \
# 0            2         0         6   18           2       4         3      4
# 1            2         0         4   17           1       5         3      3
# 2            2         3        10   15           1       4         3      2
# 3            3         0         2   15           1       3         2      2
# 4            2         0         4   16           1       4         3      2
# ..         ...       ...       ...  ...         ...     ...       ...    ...
# 390          2         2        11   20           1       5         5      4
# 391          1         0         3   17           2       2         4      5
# 392          1         3         3   21           1       5         5      3
# 393          1         0         0   18           3       4         4      1
# 394          1         0         5   19           1       3         2      3
#
#      G1  G2  G3
# 0     5   6   6
# 1     5   5   6
# 2     7   8  10
# 3    15  14  15
# 4     6  10  10
# ..   ..  ..  ..
# 390   9   9   9
# 391  14  16  16
# 392  10   8   7
# 393  11  12  10
# 394   8   9   9
#
# [395 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['studytime','failures','absences','age','traveltime','famrel','freetime','goout',
 'G1','G2']]
y = df['G3']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train, y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
df.head()
# Out:
#    studytime  failures  absences  age  traveltime  famrel  freetime  goout  \
# 0          2         0         6   18           2       4         3      4
# 1          2         0         4   17           1       5         3      3
# 2          2         3        10   15           1       4         3      2
# 3          3         0         2   15           1       3         2      2
# 4          2         0         4   16           1       4         3      2
#
#    G1  G2  G3
# 0   5   6   6
# 1   5   5   6
# 2   7   8  10
# 3  15  14  15
# 4   6  10  10

# %%
from sklearn.metrics import confusion_matrix

y_true = [1,1,1,1,0,0,0,0]
y_pred = [1,1,0,1,0,1,0,0]

cm = confusion_matrix(y_true, y_pred)

print(cm)
# Out:
# [[3 1]
#  [1 3]]
